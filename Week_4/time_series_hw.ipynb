# %%
import pandas as pd

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv"
df = pd.read_csv(url, parse_dates=["Month"], index_col="Month")

# %%
df.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# ##### Questions
# - What is the frequency of the observations?
# - How many observations are there in the dataset?

# %%
# Exercise 1
# Plot the time series

# %%
# Exercise 2
# Plot the components of the time series

# %%
# Exercise 3
# Plot ACF and PACF

# %% [markdown]
# ##### Questions
# - What is stationarity?
# - Is the time series stationary?
# - What is the difference between ACF and PACF?

# %%
# Exercise 4
# If it is not already, make the time series temporary

# %%
# Exercise 5
# Plot a time series model of your choice. Motivate the choice.
