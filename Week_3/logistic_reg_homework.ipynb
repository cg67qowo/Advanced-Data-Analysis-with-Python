# %% [markdown]
# ## Week 3 - Classification: Homework

# %% [markdown]
# ### Theoretical questions
# 1. Explain the difference between **logistic regression** and **linear regression**.
# <br><br>
# 2. What is the output of logistic regression?
# <br><br>
# 3. Why is the output of logistic regression a probability?
# <br><br>
# 4. Explain the reason behind train-test splitting.
# <br><br>
# 5. Can you directly handle categorical data in logistic regression?
# <br><br>
# 6. What does a very low AUC value mean?

# %% [markdown]
# ### Practical exercise
# We will be dealing with the stock market dataset from the book "An Introduction to Statistical Learning with Applications in Python", distributed in the ISLP package. Remember to install ISLP if you do not have it already.
# > hint: do it by running !pip install ISLP in a notebook cell

# %%
from ISLP import load_data

# %%
Smarket = load_data('Smarket')
Smarket
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %%
# Fit a logistic regression model in order to predict Direction using Lag1 through Lag5 and Volume. Remember to check for null values and to split the dataset.

# %%
# Plot a confusion matrix

# %%
# Print a classification report
